# %% [markdown]
# <a href="https://colab.research.google.com/github/GreggRodgers02/AI-Career-Fair-Planner-Notebook/blob/main/CraveIQ_Meal_Planner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CraveIQ Meal Planner**

# %% [markdown]
# ## Setup

# %%
#!pip install ddgs
#!pip install langchain_openai
#!pip install langchain_community
# Out:
# Collecting ddgs
#   Downloading ddgs-9.10.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from ddgs) (8.3.1)
# Collecting primp>=0.15.0 (from ddgs)
#   Downloading primp-0.15.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: lxml>=4.9.4 in /usr/local/lib/python3.12/dist-packages (from ddgs) (6.0.2)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Collecting fake-useragent>=2.2.0 (from ddgs)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.3.0)
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading socksio-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.1.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.15.0)
# Downloading ddgs-9.10.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.7 MB/s eta 0:00:00
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 6.6 MB/s eta 0:00:00
# Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Downloading primp-0.15.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 49.9 MB/s eta 0:00:00
# Installing collected packages: socksio, primp, fake-useragent, ddgs
# Successfully installed ddgs-9.10.0 fake-useragent-2.2.0 primp-0.15.0 socksio-1.0.0
# Collecting langchain_openai
#   Downloading langchain_openai-1.1.8-py3-none-any.whl.metadata (3.1 kB)
# Collecting langchain-core<2.0.0,>=1.2.9 (from langchain_openai)
#   Downloading langchain_core-1.2.9-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (2.16.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.9->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.9->langchain_openai) (0.6.8)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.9->langchain_openai) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.9->langchain_openai) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.9->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.9->langchain_openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.9->langchain_openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.9->langchain_openai) (0.14.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain_openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.9->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain_openai) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain_openai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain_openai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain_openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.9->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.9->langchain_openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.9->langchain_openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.5.0)
# Downloading langchain_openai-1.1.8-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 3.2 MB/s eta 0:00:00
# Downloading langchain_core-1.2.9-py3-none-any.whl (496 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.3/496.3 kB 12.0 MB/s eta 0:00:00
# Installing collected packages: langchain-core, langchain_openai
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.8
#     Uninstalling langchain-core-1.2.8:
#       Successfully uninstalled langchain-core-1.2.8
# Successfully installed langchain-core-1.2.9 langchain_openai-1.1.8
# Collecting langchain_community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (1.2.9)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Downloading langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.46)
# Collecting requests<3.0.0,>=2.32.5 (from langchain_community)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.6.8)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Downloading langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (26.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2026.1.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.3.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 30.8 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.5 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 3.5 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.6 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: requests, mypy-extensions, marshmallow, typing-inspect, dataclasses-json, langchain-text-splitters, langchain-classic, langchain_community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# Successfully installed dataclasses-json-0.6.7 langchain-classic-1.0.1 langchain-text-splitters-1.1.0 langchain_community-0.4.1 marshmallow-3.26.2 mypy-extensions-1.1.0 requests-2.32.5 typing-inspect-0.9.0

# %%
import langchain
from langchain_openai import ChatOpenAI
from langchain_core.prompts import SystemMessagePromptTemplate, HumanMessagePromptTemplate, ChatPromptTemplate
from getpass import getpass
import os
from langchain.agents import create_agent
import json
from langchain_core.output_parsers import JsonOutputParser
import ddgs
from langchain_community.tools import DuckDuckGoSearchResults
import random

# %%
os.environ["OPENAI_API_KEY"] = getpass("OpenAI API Key: ")
# Out:
# OpenAI API Key: ··········

# %%
model = ChatOpenAI(
    model_name="gpt-4o-mini",
    temperature=0.3
)

meal_planner_model = ChatOpenAI(
    model_name="gpt-4o-mini",
    temperature=0.7
)

# %%
json_parser = JsonOutputParser()

# %% [markdown]
# ## User Input

# %%
user_input = {
    "diet_restrictions": ["Vegetarian", "Low Carb"],
    "meal_plan_duration": 7,
    "saved_recipes": ["Whole Wheat Pita Pizza", "Fruit and Gelatin Gummies", "Protein-Packed Breakfast Bowl", "Greek Yogurt Cheescake"],
    "height": 72,
    "weight": 210,
    "gender": "male",
    "active_level": "moderately_active",
    "targed_weight": 195,
    "calories_intake_preferences": "balance"
}

# %%
# Duration between 7, 14, and 28
duration = input("How long is the meal plan: ")
# Out:
# How long is the meal plan: 7

# %% [markdown]
# ## Calculate Dailty Calories Intake

# %%
structured_input = json.dumps(user_input, indent=2)

# %%
calories_calculator_system = SystemMessagePromptTemplate.from_template(
    '''
You are a calorie-calculation engine for the CraveIQ Meal Planner.

Your responsibility is to compute a daily calorie goal using accepted nutrition science and conservative assumptions.

Rules:
- Use standard metabolic calculations (BMR → TDEE → calorie adjustment).
- Optimize for weight loss while preserving lean muscle.
- Never recommend extreme or unsafe calorie deficits.
- If user data is missing, infer conservatively and record assumptions.
- Do not modify total calories based on meal timing preferences.
- Do not include advice, commentary, or extraneous text.
- Output MUST be valid JSON and MUST match the specified schema exactly.
- Do NOT include markdown, explanations outside JSON, or additional keys.

You are not a conversational assistant. You are a deterministic nutrition calculator.

Return a JSON object with EXACTLY the following structure and data types:

{{
  "daily_calorie_goal": number,
  "estimated_maintenance_calories": number,
  "calorie_deficit": number,
  "assumptions": string[],
  "calculation_notes": string
}}

Field requirements:
- daily_calorie_goal: final recommended daily calories (integer).
- estimated_maintenance_calories: estimated TDEE before deficit (integer).
- calorie_deficit: difference between maintenance and goal (positive integer).
- assumptions: list any inferred values or defaults used.
- calculation_notes: one concise sentence summarizing the calculation logic.

activity level mapping:
- not_active is around 1.2
- lightly_active is around 1.375
- moderately_active is around 1.55
- very_active is around 1.725
- extremely_active is around 1.9


Constraints:
- Use safe, sustainable calorie deficits only.
- Do NOT include units (e.g., “kcal”).
- Do NOT include additional fields.
- Output valid JSON only.

    '''
)

# %%
calories_calculator_human = HumanMessagePromptTemplate.from_template(
    '''
Calculate the daily calorie goal using the user profile below.

USER INPUT:
{structured_input}
    '''
)

# %%
calories_calculator_prompt = ChatPromptTemplate.from_messages(
    [
        calories_calculator_system,
        calories_calculator_human
    ]
)

# %%
calories_calculator_chain = (
    calories_calculator_prompt
    | model
    | json_parser
)

# %%
calories_calculator_result = calories_calculator_chain.invoke(
    input={
        "structured_input": structured_input
    }
)

# %%
calories_calculator_result
# Out:
# {'daily_calorie_goal': 1800,
#  'estimated_maintenance_calories': 2500,
#  'calorie_deficit': 700,
#  'assumptions': ["User's age is assumed to be 30 years for BMR calculation.",
#   "User's activity level is moderately_active."],
#  'calculation_notes': 'Calculated daily calorie goal based on a moderate deficit from estimated TDEE.'}

# %% [markdown]
# ## Daily Meal Plan Creation

# %%
meal_type = ""
meal_calories = ""

if user_input['calories_intake_preferences'] == "balance":
  if meal_type == "breakfast":
    meal_calories = "33 percent"
  elif meal_type == "Lunch":
    meal_calories = "33 percent"
  elif meal_type == "Dinner":
    meal_calories = "33 percent"

# %%
daily_meals_system = SystemMessagePromptTemplate.from_template(
    '''
You are an innovative culinary AI for the CraveIQ Meal Planner.

CRITICAL ANTI-REPETITION RULES:
- NEVER start meal names with the same word twice
- NEVER use the same base ingredient (e.g., zucchini) consecutively
- NEVER default to "Savory" or "Classic" or "Traditional" as descriptors
- Vary your naming style: sometimes lead with protein, sometimes with cuisine, sometimes with cooking method
- Break out of any pattern you notice yourself falling into

NAMING STYLE VARIETY (rotate between these):
- Cuisine-first: "Korean Kimchi Tofu Scramble with Sesame Spinach"
- Protein-first: "Smoked Salmon & Dill Cauliflower Hash"
- Method-first: "Grilled Halloumi with Roasted Red Pepper Shakshuka"
- Ingredient-first: "Mushroom & Gruyere Cloud Eggs with Arugula"
- Simple & Direct: "Turkish Menemen with Feta"

CREATIVITY MANDATE:
- Mentally flip a coin: heads = Asian/Middle Eastern, tails = Mediterranean/Latin
- Rotate proteins AGGRESSIVELY: eggs → cheese → tofu → tempeh → salmon → etc.
- Explore global breakfast traditions beyond American/European
- Think: What would they eat for breakfast in Thailand? Morocco? Israel? Korea? Greece?
- Consider: Shakshuka, Congee, Natto, Sabich, Huevos Rancheros, Ful Medames, etc.

MEAL GENERATION APPROACH:
1. First, pick a random cuisine you haven't used recently
2. Then, find a traditional breakfast from that cuisine
3. Adapt it to meet the calorie/diet constraints
4. Name it authentically, not generically

Field requirements:
- meal_type: must exactly match the provided meal_type
- meal_name: concise, user-friendly
- estimated_calories: integer within ±10% of target_meal_calories
- diet_tags: derived from user restrictions (e.g., Vegetarian, Low Carb)

Constraints:
- Do NOT include units.
- Do NOT include extra fields.
- Output valid JSON only.

{{
  "meal_type": string,
  "meal_name": string,
  "Cuisine Culture": string,
  "estimated_calories": number,
  "diet_tags": string[]
}}

NO explanations. NO units. NO extra fields.
    '''
)

daily_meals_human = HumanMessagePromptTemplate.from_template(
    '''
Generate a CREATIVE meal that breaks any patterns.

Calories Daily Total:
{calories_calculator_result}

MEAL_CONTEXT:
- meal_type: {meal_type}
- target_meal_calories: 33 percent of Calories Daily Total

USER_PREFERENCES:
{user_input}

RANDOMIZATION CHECKPOINT:
- Do NOT start with "Savory"
- Do NOT use zucchini or chia
- Pick a cuisine: {random_cuisine_hint}
- Vary your naming structure from previous generations

Generate ONE completely different meal now.
    '''
)

# %%
# List of cuisines to randomly hint at
cuisines = [
    # Asian
    "Thai", "Korean", "Japanese", "Vietnamese", "Chinese", "Indonesian",
    "Malaysian", "Filipino", "Singaporean", "Cambodian", "Laotian", "Burmese",
    "Taiwanese", "Hong Kong", "Mongolian", "Tibetan",

    # Middle Eastern & North African
    "Lebanese", "Turkish", "Israeli", "Moroccan", "Egyptian", "Persian",
    "Syrian", "Jordanian", "Palestinian", "Tunisian", "Algerian", "Yemeni",

    # Mediterranean & European
    "Greek", "Italian", "Spanish", "Portuguese", "French", "Croatian",
    "Albanian", "Cypriot", "Maltese",

    # Latin American
    "Mexican", "Peruvian", "Brazilian", "Argentine", "Colombian", "Venezuelan",
    "Chilean", "Cuban", "Puerto Rican", "Ecuadorian", "Bolivian", "Costa Rican",

    # Caribbean
    "Jamaican", "Trinidadian", "Haitian", "Dominican", "Barbadian",

    # African
    "Ethiopian", "Nigerian", "Ghanaian", "Kenyan", "South African", "Senegalese",
    "Somali", "Eritrean", "Ugandan", "Tanzanian",

    # Indian Subcontinent
    "Indian", "Pakistani", "Bangladeshi", "Sri Lankan", "Nepali",

    # Eastern European
    "Polish", "Ukrainian", "Russian", "Hungarian", "Czech", "Georgian",
    "Armenian", "Romanian", "Bulgarian",

    # Nordic
    "Swedish", "Norwegian", "Danish", "Finnish", "Icelandic",

    #American Regional & Cultural
    "Southern Soul Food", "Cajun", "Creole", "Tex-Mex", "New England",
    "Pacific Northwest", "California Coastal", "Southwest American",
    "Midwest Heartland", "Appalachian", "Jewish American", "Italian American",
    "Chinese American", "Korean American", "Vietnamese American",
    "Filipino American", "Native American", "Pennsylvania Dutch",
    "Louisiana Creole", "Low Country", "Carolina BBQ", "Kansas City BBQ",
    "Texas BBQ", "Memphis BBQ", "Hawaiian", "Alaskan", "Southern Comfort",
    "American Diner", "Classic American", "Contemporary American",

    # Other
    "Australian", "New Zealand", "Hawaiian", "Cajun", "Creole", "Soul Food",
    "Tex-Mex", "Fusion"
]

# %%
daily_meals_prompt = ChatPromptTemplate.from_messages(
    [
        daily_meals_system,
        daily_meals_human
    ]
)

# %%
daily_meals_chain = (
    daily_meals_prompt
    | meal_planner_model
    | json_parser
)

# %%
daily_meal_result = daily_meals_chain.batch([
    {
        "calories_calculator_result": calories_calculator_result,
        "meal_type": "Breakfast",
        "user_input": user_input,
        "random_cuisine_hint": random.choice(cuisines)
    },
    {
        "calories_calculator_result": calories_calculator_result,
        "meal_type": "Lunch",
        "user_input": user_input,
        "random_cuisine_hint": random.choice(cuisines)
    },
    {
        "calories_calculator_result": calories_calculator_result,
        "meal_type": "Dinner",
        "user_input": user_input,
        "random_cuisine_hint": random.choice(cuisines)
    }
])
daily_meal_result
# Out:
# [{'meal_type': 'Breakfast',
#   'meal_name': 'Finnish Rye Porridge with Berries and Almonds',
#   'Cuisine Culture': 'Finnish',
#   'estimated_calories': 600,
#   'diet_tags': ['Vegetarian', 'Low Carb']},
#  {'meal_type': 'Lunch',
#   'meal_name': 'Tibetan Vegetable Tsampa Bowl with Spiced Green Chutney',
#   'Cuisine Culture': 'Tibetan',
#   'estimated_calories': 600,
#   'diet_tags': ['Vegetarian', 'Low Carb']},
#  {'meal_type': 'Dinner',
#   'meal_name': 'Ratatouille-Stuffed Bell Peppers with Herbed Quinoa',
#   'Cuisine Culture': 'French',
#   'estimated_calories': 600,
#   'diet_tags': ['Vegetarian', 'Low Carb']}]

# %%
search = DuckDuckGoSearchResults()

agent_system_message = '''
 You are a renowned food nutritionist specializing in fat loss. Your job is to analyze the suggested meal and create a detailed, healthy recipe that satisfies this meal while supporting fat loss and a healthy lifestyle.

When responding, provide:
- Recipe name (matching the suggested meal)
- Cuisine Culture name
- Amount of calories
- Complete ingredient list
- Clear step-by-step cooking instructions
- Why this recipe supports fat loss and health goals
- Nutritional highlights of key ingredients
- Motivation and encouragement for the user

CRITICAL REQUIREMENTS:
- Total recipe calories MUST match the target calorie count (±10%)
- Respect ALL dietary restrictions provided
- Use whole, minimally processed ingredients
- Focus on lean proteins, healthy fats, and fiber-rich foods
- Make portions realistic and satisfying
 '''

# Create agent once with the template
daily_meals_agent = create_agent(
    model=model,
    system_prompt=agent_system_message,
    tools=[search]
)

# Invoke with actual values - LangChain will substitute them
daily_meal_agent_results = daily_meals_agent.batch([
    {"messages": [("user", json.dumps(daily_meal_result[0], indent=2))]},
    {"messages": [("user", json.dumps(daily_meal_result[1], indent=2))]},
    {"messages": [("user", json.dumps(daily_meal_result[2], indent=2))]}
])

# %%
breakfast = daily_meal_agent_results[0]['messages'][1].content
lunch = daily_meal_agent_results[1]['messages'][1].content
dinner = daily_meal_agent_results[2]['messages'][1].content

# %%
print(dinner)
# Out:
# ### Recipe Name: Ratatouille-Stuffed Bell Peppers with Herbed Quinoa
#
# ### Cuisine Culture: French
#
# ### Total Calories: 600
#
# ---
#
# ### Complete Ingredient List:
#
# #### For the Stuffed Bell Peppers:
# - 4 medium bell peppers (any color)
# - 1 medium zucchini, diced
# - 1 medium eggplant, diced
# - 1 medium onion, diced
# - 2 cloves garlic, minced
# - 1 medium tomato, diced
# - 1 teaspoon dried thyme
# - 1 teaspoon dried basil
# - 1 tablespoon olive oil
# - Salt and pepper to taste
#
# #### For the Herbed Quinoa:
# - 1 cup quinoa, rinsed
# - 2 cups vegetable broth (low sodium)
# - 1 tablespoon fresh parsley, chopped
# - 1 tablespoon fresh basil, chopped
# - 1 tablespoon lemon juice
# - Salt and pepper to taste
#
# ---
#
# ### Step-by-Step Cooking Instructions:
#
# 1. **Prepare the Quinoa:**
#    - In a medium saucepan, combine the rinsed quinoa and vegetable broth. Bring to a boil over medium-high heat.
#    - Once boiling, reduce the heat to low, cover, and simmer for about 15 minutes or until the quinoa is fluffy and the liquid is absorbed.
#    - Remove from heat and let it sit covered for 5 minutes. Fluff with a fork and stir in parsley, basil, lemon juice, salt, and pepper. Set aside.
#
# 2. **Prepare the Ratatouille Filling:**
#    - Preheat your oven to 375°F (190°C).
#    - In a large skillet, heat olive oil over medium heat. Add the diced onion and garlic, sautéing until the onion is translucent.
#    - Add the diced zucchini, eggplant, and tomato to the skillet. Season with thyme, basil, salt, and pepper. Cook for about 10-12 minutes, stirring occasionally, until the vegetables are tender.
#
# 3. **Stuff the Bell Peppers:**
#    - While the ratatouille is cooking, slice the tops off the bell peppers and remove the seeds.
#    - Once the ratatouille is cooked, mix it with the prepared quinoa in a large bowl.
#    - Stuff each bell pepper with the ratatouille-quinoa mixture, packing it down gently.
#
# 4. **Bake the Stuffed Peppers:**
#    - Place the stuffed bell peppers upright in a baking dish. If they don’t stand well, you can slice a small amount off the bottom to stabilize them.
#    - Cover the dish with foil and bake for 25-30 minutes. Remove the foil and bake for an additional 10 minutes to slightly char the tops.
#
# 5. **Serve:**
#    - Remove from the oven and let cool for a few minutes before serving. Garnish with additional fresh herbs if desired.
#
# ---
#
# ### Why This Recipe Supports Fat Loss and Health Goals:
# This recipe is packed with vegetables, which are low in calories but high in fiber, helping you feel full longer. The quinoa provides a complete protein source, essential for muscle maintenance while losing fat. The use of healthy fats from olive oil supports heart health without adding excessive calories. The dish is vegetarian and low in carbs, making it suitable for various dietary preferences.
#
# ### Nutritional Highlights of Key Ingredients:
# - **Bell Peppers:** High in vitamins A and C, antioxidants, and low in calories.
# - **Quinoa:** A complete protein containing all nine essential amino acids, high in fiber, and gluten-free.
# - **Zucchini and Eggplant:** Low-calorie vegetables that add volume and nutrients without excess calories.
# - **Olive Oil:** A source of healthy monounsaturated fats that can help reduce inflammation.
#
# ### Motivation and Encouragement:
# You are making a fantastic choice for your dinner tonight! This Ratatouille-Stuffed Bell Peppers with Herbed Quinoa is not only delicious but also nourishing for your body. Embrace the flavors of French cuisine while staying aligned with your health goals. Remember, every healthy meal is a step towards a healthier you. Enjoy your cooking and the wonderful meal ahead!

# %% [markdown]
# ## Meal Plan Structure Data

# %%
meal_plan_structure_system = SystemMessagePromptTemplate.from_template(
    '''
    You are a food nutritionist specializing in fat loss. Your task is to extract and structure recipe information into a valid JSON format.

CRITICAL: The Nutritionist_agent_result is your ONLY source of truth. You must extract information directly from it and NOT create, invent, or add any information that is not explicitly present in the Nutritionist_agent_result.

You must return ONLY a JSON object with this exact structure:
{{
  "recipes": [
    {{
      "name": "Recipe name",
      "cuisine_culture": "Cuisine name",
      "total_calories": number,
      "ingredients": ["ingredient 1", "ingredient 2", ...],
      "instructions": ["step 1", "step 2", ...],
      "why_healthier": "Explanation of why this is healthier"
    }},
    {{
      "name": "Recipe name 2",
      "ingredients": ["ingredient 1", "ingredient 2", ...],
      "instructions": ["step 1", "step 2", ...],
      "why_healthier": "Explanation of why this is healthier"
    }}
  ],
  "summary": "Brief summary of both recipes and their nutritional benefits",
  "motivation": "Motivational message to encourage the user to stick with their diet"
}}

Return ONLY valid JSON. No additional text before or after the JSON."""

    '''
)

# %%
meal_plan_structure_human = HumanMessagePromptTemplate.from_template(
    '''
Meal Plan Recommendations (SOURCE OF TRUTH - DO NOT ADD OR MODIFY):
{daily_meal_agent_results}

Extract and parse the information from the Nutritionist Agent's Recommendations above. Format it into the required JSON structure with two recipes, a summary, and a motivational message.

Remember: Use ONLY the information provided in the Nutritionist_agent_result. Do not add, invent, or modify any details.
    '''
)

# %%
meal_plan_structure_prompt = ChatPromptTemplate.from_messages(
    [
        meal_plan_structure_system,
        meal_plan_structure_human
    ]
)

# %%
meal_plan_structure_chain = (
    meal_plan_structure_prompt
    | model
    | json_parser
)

# %%
meal_plan_structure_result = meal_plan_structure_chain.batch([
    {
        "daily_meal_agent_results": breakfast
    },
    {
        "daily_meal_agent_results": lunch
    },
    {
        "daily_meal_agent_results": dinner
    }
])

# %%
meal_plan_structure_result[2]["recipes"][0]
# Out:
# {'name': 'Ratatouille-Stuffed Bell Peppers with Herbed Quinoa',
#  'cuisine_culture': 'French',
#  'total_calories': 600,
#  'ingredients': ['4 medium bell peppers (any color)',
#   '1 medium zucchini, diced',
#   '1 medium eggplant, diced',
#   '1 medium onion, diced',
#   '2 cloves garlic, minced',
#   '1 medium tomato, diced',
#   '1 teaspoon dried thyme',
#   '1 teaspoon dried basil',
#   '1 tablespoon olive oil',
#   'Salt and pepper to taste',
#   '1 cup quinoa, rinsed',
#   '2 cups vegetable broth (low sodium)',
#   '1 tablespoon fresh parsley, chopped',
#   '1 tablespoon fresh basil, chopped',
#   '1 tablespoon lemon juice'],
#  'instructions': ['In a medium saucepan, combine the rinsed quinoa and vegetable broth. Bring to a boil over medium-high heat.',
#   'Once boiling, reduce the heat to low, cover, and simmer for about 15 minutes or until the quinoa is fluffy and the liquid is absorbed.',
#   'Remove from heat and let it sit covered for 5 minutes. Fluff with a fork and stir in parsley, basil, lemon juice, salt, and pepper. Set aside.',
#   'Preheat your oven to 375°F (190°C).',
#   'In a large skillet, heat olive oil over medium heat. Add the diced onion and garlic, sautéing until the onion is translucent.',
#   'Add the diced zucchini, eggplant, and tomato to the skillet. Season with thyme, basil, salt, and pepper. Cook for about 10-12 minutes, stirring occasionally, until the vegetables are tender.',
#   'While the ratatouille is cooking, slice the tops off the bell peppers and remove the seeds.',
#   'Once the ratatouille is cooked, mix it with the prepared quinoa in a large bowl.',
#   'Stuff each bell pepper with the ratatouille-quinoa mixture, packing it down gently.',
#   'Place the stuffed bell peppers upright in a baking dish. If they don’t stand well, you can slice a small amount off the bottom to stabilize them.',
#   'Cover the dish with foil and bake for 25-30 minutes. Remove the foil and bake for an additional 10 minutes to slightly char the tops.',
#   'Remove from the oven and let cool for a few minutes before serving. Garnish with additional fresh herbs if desired.'],
#  'why_healthier': 'This recipe is packed with vegetables, which are low in calories but high in fiber, helping you feel full longer. The quinoa provides a complete protein source, essential for muscle maintenance while losing fat. The use of healthy fats from olive oil supports heart health without adding excessive calories. The dish is vegetarian and low in carbs, making it suitable for various dietary preferences.'}

# %% [markdown]
# ## Get Meal Plan for Duration

# %%
days = int(duration)

# %%
full_meal_plan = {}

# %%
for i in range(days):
  daily_meal_result = daily_meals_chain.batch([
    {
        "calories_calculator_result": calories_calculator_result,
        "meal_type": "Breakfast",
        "user_input": user_input,
        "random_cuisine_hint": random.choice(cuisines)
    },
    {
        "calories_calculator_result": calories_calculator_result,
        "meal_type": "Lunch",
        "user_input": user_input,
        "random_cuisine_hint": random.choice(cuisines)
    },
    {
        "calories_calculator_result": calories_calculator_result,
        "meal_type": "Dinner",
        "user_input": user_input,
        "random_cuisine_hint": random.choice(cuisines)
    }
])
  daily_meal_agent_results = daily_meals_agent.batch([
    {"messages": [("user", json.dumps(daily_meal_result[0], indent=2))]},
    {"messages": [("user", json.dumps(daily_meal_result[1], indent=2))]},
    {"messages": [("user", json.dumps(daily_meal_result[2], indent=2))]}
])
  breakfast = daily_meal_agent_results[0]['messages'][1].content
  lunch = daily_meal_agent_results[1]['messages'][1].content
  dinner = daily_meal_agent_results[2]['messages'][1].content
  meal_plan_structure_result = meal_plan_structure_chain.batch([
    {
        "daily_meal_agent_results": breakfast
    },
    {
        "daily_meal_agent_results": lunch
    },
    {
        "daily_meal_agent_results": dinner
    }
])
  full_meal_plan[i] = {
      "breakfast": meal_plan_structure_result[0]["recipes"][0],
      "lunch": meal_plan_structure_result[1]["recipes"][0],
      "dinner": meal_plan_structure_result[2]["recipes"][0]
  }
  print(f"Day {i + 1} completed")
  print(full_meal_plan[i])
# Out:
# Day 1 completed
# {'breakfast': {'name': 'Shakshuka with Spinach and Feta', 'cuisine_culture': 'Israeli', 'total_calories': 600, 'ingredients': ['2 tablespoons olive oil', '1 medium onion, diced', '2 cloves garlic, minced', '1 red bell pepper, diced', '1 teaspoon ground cumin', '1 teaspoon smoked paprika', '1 can (14 oz) diced tomatoes (no added sugar)', '4 large eggs', '2 cups fresh spinach', '1/2 cup feta cheese, crumbled', 'Salt and pepper to taste', 'Fresh parsley or cilantro for garnish (optional)'], 'instructions': ['In a large skillet, heat the olive oil over medium heat.', 'Add the diced onion and red bell pepper to the skillet. Sauté for about 5-7 minutes until the onion is translucent and the peppers are soft. Add the minced garlic and sauté for another minute until fragrant.', 'Stir in the ground cumin and smoked paprika, cooking for an additional minute to toast the spices.', 'Pour in the canned diced tomatoes (with their juices) and season with salt and pepper. Let the mixture simmer for about 10 minutes, stirring occasionally, until it thickens slightly.', 'Add the fresh spinach to the skillet and stir until wilted, about 2-3 minutes.', 'Using a spoon, create four small wells in the tomato mixture. Crack an egg into each well.', 'Cover the skillet with a lid and cook for about 5-7 minutes, or until the egg whites are set but the yolks are still runny (or to your desired doneness).', 'Sprinkle the crumbled feta cheese over the top and cover for another minute to allow it to soften slightly.', 'Remove from heat, garnish with fresh parsley or cilantro if desired, and serve warm.'], 'why_healthier': 'This Shakshuka recipe is rich in protein from the eggs and feta, which helps to keep you feeling full and satisfied. The inclusion of spinach adds fiber and essential nutrients while keeping the calorie count low. Olive oil provides healthy fats that are beneficial for heart health. The dish is low in carbohydrates, making it suitable for those looking to reduce their carb intake while still enjoying a hearty meal.'}, 'lunch': {'name': 'Carolina BBQ Tofu Bowl with Collard Greens', 'cuisine_culture': 'Southern American', 'total_calories': 600, 'ingredients': ['1 block (14 oz) firm tofu', '2 tablespoons olive oil', '1/4 cup low-sugar BBQ sauce', '1 teaspoon smoked paprika', '1 teaspoon garlic powder', 'Salt and pepper to taste', '4 cups fresh collard greens, chopped', '1 tablespoon olive oil', '1 clove garlic, minced', '1/2 teaspoon red pepper flakes (optional)', '1 tablespoon apple cider vinegar', '1/4 cup diced tomatoes', '1/4 avocado, sliced'], 'instructions': ['Press the tofu for about 15-20 minutes to remove excess moisture. Cut it into bite-sized cubes.', 'In a bowl, mix the olive oil, BBQ sauce, smoked paprika, garlic powder, salt, and pepper. Add the tofu cubes and toss to coat evenly.', 'Preheat a non-stick skillet over medium heat. Add the tofu and cook for about 5-7 minutes until golden brown, turning occasionally.', 'In another skillet, heat 1 tablespoon of olive oil over medium heat. Add minced garlic and sauté for 1 minute until fragrant.', 'Add the chopped collard greens and red pepper flakes (if using). Sauté for about 5-7 minutes until the greens are tender.', 'Stir in the apple cider vinegar and season with salt and pepper to taste.', 'In a serving bowl, layer the sautéed collard greens as the base.', 'Top with the BBQ tofu, diced tomatoes, and sliced avocado.', 'Drizzle any remaining BBQ sauce over the top if desired.', 'Serve immediately while warm and enjoy your delicious Carolina BBQ Tofu Bowl!'], 'why_healthier': 'This recipe is designed to be low in carbohydrates while providing a satisfying meal rich in protein and healthy fats. The use of tofu as a protein source is beneficial for muscle maintenance and satiety, while the collard greens add fiber and essential nutrients without adding many calories. The healthy fats from olive oil and avocado help keep you full longer and support overall health.'}, 'dinner': {'name ...
# Day 2 completed
# {'breakfast': {'name': 'Kelewele with Avocado & Spiced Chickpeas', 'cuisine_culture': 'Ghanaian', 'total_calories': 600, 'ingredients': ['2 medium ripe plantains', '1 tablespoon ginger, grated', '1 tablespoon garlic, minced', '1 teaspoon cayenne pepper', '1 teaspoon paprika', '1 tablespoon coconut oil', 'Salt to taste', '1 cup canned chickpeas, drained and rinsed', '1 tablespoon olive oil', '1 teaspoon cumin', '1 teaspoon smoked paprika', 'Salt and pepper to taste', '1 medium avocado'], 'instructions': ['Peel and slice plantains into bite-sized cubes.', 'In a bowl, combine grated ginger, minced garlic, cayenne pepper, paprika, and salt.', 'Toss plantain cubes in the spice mixture until evenly coated.', 'Heat coconut oil in a frying pan over medium heat. Add spiced plantains and fry until golden brown and crispy, about 5-7 minutes.', 'Remove from the pan and place on a paper towel to drain excess oil.', 'In a separate pan, heat olive oil over medium heat.', 'Add drained chickpeas to the pan and sauté for about 5 minutes.', 'Sprinkle cumin, smoked paprika, salt, and pepper over the chickpeas. Stir well and cook for another 3-5 minutes until heated through and slightly crispy.', 'Cut the avocado in half, remove the pit, and slice it into wedges.', 'On a serving plate, arrange the crispy Kelewele, spiced chickpeas, and avocado slices.', 'Optional: Add a sprinkle of fresh herbs like cilantro or parsley for added flavor.'], 'why_healthier': 'This recipe is designed to be nutrient-dense while remaining low in refined carbohydrates. The combination of plantains, chickpeas, and avocado provides a balance of healthy fats, fiber, and protein, which helps keep you full longer and supports weight management.'}, 'lunch': {'name': 'Trinidadian Callaloo with Coconut Spinach', 'cuisine_culture': 'Trinidadian', 'total_calories': 600, 'ingredients': ['2 cups fresh spinach (or 1 cup frozen spinach)', '1 cup callaloo (or substitute with Swiss chard or kale)', '1 cup coconut milk (light)', '1 medium onion, chopped', '2 cloves garlic, minced', '1 medium tomato, diced', '1 bell pepper (any color), diced', '1 tablespoon olive oil', '1 teaspoon thyme (fresh or dried)', '1 teaspoon black pepper', '1/2 teaspoon salt (or to taste)', '1/2 teaspoon cayenne pepper (optional, for heat)', '1/4 cup vegetable broth (low sodium)', '1 tablespoon lime juice', '1/4 cup green onions, chopped (for garnish)'], 'instructions': ['Prepare the Ingredients: Wash and chop the spinach, callaloo (or substitute), onion, garlic, tomato, and bell pepper. Set aside.', 'Sauté Aromatics: In a large pot, heat the olive oil over medium heat. Add the chopped onion and garlic, and sauté until the onion becomes translucent (about 3-4 minutes).', 'Add Vegetables: Stir in the diced tomato and bell pepper. Cook for another 2-3 minutes until the vegetables soften.', 'Incorporate Greens: Add the spinach and callaloo to the pot. Stir well to combine with the sautéed vegetables.', 'Add Coconut Milk and Seasonings: Pour in the coconut milk and vegetable broth. Add thyme, black pepper, salt, and cayenne pepper (if using). Stir everything together.', 'Simmer: Reduce the heat to low, cover the pot, and let it simmer for about 10-15 minutes, allowing the flavors to meld and the greens to wilt.', 'Finish with Lime Juice: Once cooked, remove from heat and stir in the lime juice for a fresh flavor boost.', 'Serve: Garnish with chopped green onions before serving. Enjoy your Trinidadian Callaloo with Coconut Spinach warm.'], 'why_healthier': 'This recipe is designed to be low in calories while being high in nutrients. The use of leafy greens like spinach and callaloo provides fiber, which aids in digestion and promotes satiety, helping to control hunger. The coconut milk adds a creamy texture without excessive calories, and the healthy fats from olive oil and coconut milk can help keep you satisfied longer.'}, 'dinner': {'name': 'Senegalese Yassa Tofu with Spicy Carrots', 'cuisine_culture': 'Senegalese' ...
# Day 3 completed
# {'breakfast': {'name': 'Cajun Spiced Eggplant & Chickpea Hash with Avocado', 'cuisine_culture': 'Louisiana Creole', 'total_calories': 600, 'ingredients': ['1 medium eggplant (about 1 lb)', '1 can (15 oz) chickpeas, drained and rinsed', '1 medium red bell pepper, diced', '1 small onion, diced', '2 cloves garlic, minced', '1 tablespoon olive oil', '1 teaspoon Cajun seasoning', '1/2 teaspoon smoked paprika', 'Salt and pepper to taste', '1 medium avocado, diced', 'Fresh cilantro for garnish (optional)'], 'instructions': ['Prepare the Ingredients: Start by washing and dicing the eggplant, red bell pepper, and onion. Mince the garlic.', 'Sauté the Vegetables: In a large skillet, heat the olive oil over medium heat. Add the diced onion and garlic, and sauté for about 2-3 minutes until the onion becomes translucent.', 'Cook the Eggplant: Add the diced eggplant to the skillet. Cook for about 5-7 minutes, stirring occasionally, until the eggplant is tender and slightly browned.', 'Add Chickpeas and Spices: Stir in the drained chickpeas, Cajun seasoning, smoked paprika, salt, and pepper. Cook for an additional 5 minutes, allowing the flavors to meld together.', 'Incorporate the Bell Pepper: Add the diced red bell pepper to the skillet and cook for another 3-4 minutes until the pepper is tender but still crisp.', 'Serve: Remove from heat and top the hash with diced avocado. Garnish with fresh cilantro if desired.', 'Enjoy: Serve warm and enjoy your nutritious breakfast!'], 'why_healthier': 'This Cajun Spiced Eggplant & Chickpea Hash is rich in fiber from the eggplant and chickpeas, which helps keep you full longer and supports digestive health. The healthy fats from the avocado provide satiety while also delivering essential nutrients. The use of spices not only adds flavor but can also boost metabolism.'}, 'lunch': {'name': 'Crispy Tofu & Cabbage Slaw with Apple Cider Vinaigrette', 'cuisine_culture': 'Midwest Heartland', 'total_calories': 600, 'ingredients': ['14 oz firm tofu (drained and pressed)', '2 tbsp cornstarch', '1 tbsp olive oil', 'Salt and pepper to taste', '2 cups green cabbage, finely shredded', '1 cup red cabbage, finely shredded', '1 carrot, grated', '1/4 cup green onions, chopped', '1/4 cup fresh cilantro, chopped (optional)', '3 tbsp apple cider vinegar', '1 tbsp Dijon mustard', '1 tbsp honey or agave syrup (optional for sweetness)', '2 tbsp olive oil', 'Salt and pepper to taste'], 'instructions': ['Preheat your oven to 400°F (200°C).', 'Cut the pressed tofu into bite-sized cubes.', 'In a bowl, toss the tofu cubes with cornstarch, salt, and pepper until evenly coated.', 'Spread the tofu on a baking sheet lined with parchment paper and drizzle with olive oil.', 'Bake for 25-30 minutes, flipping halfway through, until golden and crispy.', 'In a large bowl, combine the green cabbage, red cabbage, grated carrot, green onions, and cilantro (if using).', 'In a separate small bowl, whisk together the apple cider vinegar, Dijon mustard, honey or agave syrup, olive oil, salt, and pepper until well combined.', 'Pour the vinaigrette over the slaw and toss to coat evenly. Let it sit for about 10 minutes to allow the flavors to meld.', 'Once the tofu is crispy, remove it from the oven.', 'Serve the crispy tofu over a generous portion of the cabbage slaw.', 'Drizzle any remaining vinaigrette over the top for extra flavor.'], 'why_healthier': 'This recipe is designed to be low in carbohydrates while providing a satisfying meal rich in plant-based proteins and healthy fats. The crispy tofu serves as a great source of protein, which helps to keep you full and satisfied without excess calories. The cabbage slaw is high in fiber, aiding in digestion and promoting a feeling of fullness. The apple cider vinaigrette adds flavor without excessive calories, making this dish both delicious and nutritious.'}, 'dinner': {'name': 'Cilantro-Lime Cauliflower Rice with Spicy Black Beans', 'cuisine_culture': 'Mexican', 'total_calories': 600, 'ingredient ...
# Day 4 completed
# {'breakfast': {'name': 'Southern-Style Grits with Spinach and Poached Egg', 'cuisine_culture': 'Low Country', 'total_calories': 600, 'ingredients': ['1 cup stone-ground grits (uncooked)', '4 cups water', '1/2 cup unsweetened almond milk', '1/2 cup shredded low-fat cheddar cheese', 'Salt and pepper to taste', '2 cups fresh spinach', '1 tablespoon olive oil', '2 cloves garlic, minced', '2 large eggs', '1 tablespoon vinegar (for poaching)', '1 tablespoon chopped fresh parsley', 'A sprinkle of red pepper flakes (optional)'], 'instructions': ['In a medium saucepan, bring 4 cups of water to a boil. Add a pinch of salt.', 'Gradually whisk in the stone-ground grits. Reduce heat to low, cover, and simmer for about 20-25 minutes, stirring occasionally until thickened.', 'Once the grits are cooked, stir in the almond milk and shredded cheddar cheese. Mix until creamy and season with salt and pepper to taste. Keep warm.', 'In a skillet, heat 1 tablespoon of olive oil over medium heat. Add minced garlic and sauté for about 1 minute until fragrant.', 'Add the fresh spinach and cook until wilted, about 2-3 minutes. Season with salt and pepper. Remove from heat.', 'In a saucepan, bring water to a gentle simmer and add 1 tablespoon of vinegar.', 'Crack each egg into a small bowl. Gently slide the eggs into the simmering water, one at a time. Cook for about 3-4 minutes for a runny yolk or longer if desired.', 'Remove the eggs with a slotted spoon and let them drain on a paper towel.', 'Spoon the cheesy grits into a bowl. Top with sautéed spinach and place a poached egg on top of each serving.', 'Garnish with chopped parsley and a sprinkle of red pepper flakes if desired.'], 'why_healthier': 'This recipe is designed to be nutrient-dense while remaining low in calories. The combination of stone-ground grits provides a good source of fiber, which aids in digestion and keeps you feeling full longer. Spinach is low in calories but high in vitamins and minerals, while the poached eggs offer high-quality protein that supports muscle maintenance and satiety. The use of almond milk and low-fat cheese keeps the dish creamy without adding excessive calories or saturated fat.'}, 'lunch': {'name': 'Malaysian Nasi Ulam with Tofu and Herbs', 'cuisine_culture': 'Malaysian', 'total_calories': 600, 'ingredients': ['1 cup cauliflower rice', '1/2 cup cooked brown rice', '1/2 cup shredded cabbage', '1/4 cup chopped fresh mint', '1/4 cup chopped fresh cilantro', '1/4 cup chopped green onions', '1/4 cup diced cucumber', '1 tablespoon lime juice', '1 tablespoon olive oil', 'Salt and pepper to taste', '200g firm tofu', '1 tablespoon soy sauce', '1 teaspoon sesame oil', '1 teaspoon grated ginger', '1 clove garlic, minced', '1/2 teaspoon turmeric powder'], 'instructions': ['Press the tofu to remove excess moisture. Cut it into cubes.', 'In a bowl, mix soy sauce, sesame oil, ginger, garlic, and turmeric. Add the tofu cubes and marinate for at least 15 minutes.', 'Heat a non-stick skillet over medium heat. Add the marinated tofu and cook until golden brown on all sides, about 8-10 minutes. Remove from heat and set aside.', 'In a large bowl, combine cauliflower rice, cooked brown rice, shredded cabbage, mint, cilantro, green onions, and cucumber.', 'Drizzle with olive oil and lime juice. Season with salt and pepper to taste. Toss everything together until well mixed.', 'On a plate, serve a generous portion of the Nasi Ulam topped with the golden tofu. Garnish with additional herbs if desired.'], 'why_healthier': 'This Malaysian Nasi Ulam with Tofu and Herbs is a perfect meal for those looking to lose fat while enjoying a flavorful dish. The use of cauliflower rice significantly reduces the carbohydrate content while increasing fiber intake, which helps keep you full longer. Tofu provides a great source of plant-based protein, essential for muscle maintenance during weight loss. The fresh herbs and vegetables add vitamins, minerals, and antioxidants, contributing to overall  ...
# Day 5 completed
# {'breakfast': {'name': 'Posho with Avocado and Tomato Salsa', 'cuisine_culture': 'Ugandan', 'total_calories': 600, 'ingredients': ['1 cup maize flour (cornmeal)', '2 cups water', '1/4 teaspoon salt', '1 medium avocado', '1 medium tomato, diced', '1/4 red onion, finely chopped', '1 tablespoon fresh lime juice', '1 tablespoon fresh cilantro, chopped', 'Salt and pepper to taste'], 'instructions': ['In a medium saucepan, bring 2 cups of water to a boil. Add 1/4 teaspoon of salt.', 'In a separate bowl, mix 1 cup of maize flour with a little cold water to create a smooth paste.', 'Once the water is boiling, gradually add the maize flour paste to the boiling water while stirring continuously to avoid lumps.', 'Reduce the heat to low and continue stirring for about 10-15 minutes until the mixture thickens and pulls away from the sides of the pan.', 'Once cooked, transfer the posho to a plate and shape it into a round or oval mound.', 'In a mixing bowl, combine the diced tomato, chopped red onion, and chopped cilantro.', 'Cut the avocado in half, remove the pit, and scoop the flesh into the bowl. Gently mash it with a fork to combine with the other ingredients.', 'Add lime juice, salt, and pepper to taste. Mix well to combine all the flavors.', 'Serve the posho warm, topped with a generous scoop of the avocado and tomato salsa.'], 'why_healthier': 'High Fiber: The maize flour and vegetables provide dietary fiber, which aids digestion and promotes a feeling of fullness, helping to control appetite. Healthy Fats: Avocado is rich in monounsaturated fats, which are heart-healthy and can help reduce bad cholesterol levels. Low Carb: This meal is relatively low in carbohydrates, making it suitable for those following a low-carb diet while still providing essential nutrients. Vegetarian: This recipe is entirely plant-based, making it suitable for vegetarians and those looking to incorporate more plant foods into their diet.'}, 'lunch': {'name': 'Laotian Larb Tofu Salad with Fresh Herbs', 'cuisine_culture': 'Laotian', 'total_calories': 600, 'ingredients': ['14 oz (400g) firm tofu, drained and pressed', '2 tablespoons olive oil', '1 tablespoon soy sauce (low sodium)', '1 tablespoon lime juice', '1 tablespoon rice vinegar', '1 teaspoon chili flakes (adjust to taste)', '1 teaspoon ground coriander', '1 teaspoon ground cumin', '1 cup red cabbage, finely shredded', '1 cup carrots, grated', '1 cup cucumber, diced', '1/2 cup green onions, chopped', '1/2 cup fresh mint leaves, chopped', '1/2 cup fresh cilantro leaves, chopped', '1/4 cup roasted peanuts, crushed (optional)', 'Salt and pepper to taste'], 'instructions': ['Cut the pressed tofu into small cubes.', 'Heat 1 tablespoon of olive oil in a non-stick skillet over medium heat.', 'Add the tofu cubes and sauté until golden brown on all sides, about 8-10 minutes.', 'Remove from heat and let cool slightly.', 'In a small bowl, whisk together the soy sauce, lime juice, rice vinegar, chili flakes, ground coriander, ground cumin, and the remaining tablespoon of olive oil. Adjust seasoning with salt and pepper to taste.', 'In a large mixing bowl, combine the shredded red cabbage, grated carrots, diced cucumber, chopped green onions, mint, and cilantro.', 'Add the sautéed tofu to the salad mixture.', 'Pour the dressing over the salad and gently toss to combine all ingredients evenly.', 'Divide the salad into bowls and top with crushed roasted peanuts if desired for added crunch. Enjoy immediately!'], 'why_healthier': 'This Laotian Larb Tofu Salad is packed with plant-based protein from tofu, which helps to keep you full and satisfied while supporting muscle maintenance during weight loss. The fresh vegetables provide fiber, which aids in digestion and promotes satiety. The use of healthy fats from olive oil and peanuts (optional) adds flavor and helps in the absorption of fat-soluble vitamins. The low-carb nature of the salad makes it suitable for those looking to reduce carbohydrate intake.'}, 'dinner': { ...
# Day 6 completed
# {'breakfast': {'name': 'Czech Cottage Cheese Pancakes with Berry Compote', 'cuisine_culture': 'Czech', 'total_calories': 590, 'ingredients': ['1 cup (240g) low-fat cottage cheese', '2 large eggs', '1/2 cup (60g) almond flour', '1/4 cup (30g) oat flour', '1 tsp vanilla extract', '1/2 tsp baking powder', '1/4 tsp salt', 'Cooking spray or a small amount of coconut oil for frying', '1 cup mixed berries (fresh or frozen, such as blueberries, raspberries, and strawberries)', '1 tbsp honey or maple syrup (optional, adjust based on sweetness preference)', '1 tsp lemon juice', '1/2 tsp cinnamon (optional)'], 'instructions': ['In a small saucepan, combine the mixed berries, honey (if using), lemon juice, and cinnamon.', 'Cook over medium heat for about 5-7 minutes, stirring occasionally until the berries break down and the mixture thickens slightly. Remove from heat and set aside.', 'In a mixing bowl, whisk together the cottage cheese and eggs until well combined.', 'Add the almond flour, oat flour, vanilla extract, baking powder, and salt. Mix until a smooth batter forms.', 'Heat a non-stick skillet over medium heat and lightly grease it with cooking spray or coconut oil.', 'Pour about 1/4 cup of the batter onto the skillet for each pancake. Cook for 3-4 minutes or until bubbles form on the surface and the edges look set.', 'Flip the pancakes and cook for an additional 2-3 minutes until golden brown. Repeat with the remaining batter.', 'Stack the pancakes on a plate and top with the warm berry compote. Enjoy your delicious Czech breakfast!'], 'why_healthier': 'This recipe is designed to be low in carbohydrates while providing a good source of protein from the cottage cheese and eggs, which helps to keep you full and satisfied. The use of almond and oat flour adds healthy fats and fiber, contributing to better digestion and sustained energy levels. The berry compote adds natural sweetness and antioxidants without excessive sugar.'}, 'lunch': {'name': 'Sri Lankan Coconut Lentil Curry', 'cuisine_culture': 'Sri Lankan', 'total_calories': 600, 'ingredients': ['1 cup red lentils (dry)', '1 can (400ml) light coconut milk', '1 medium onion, finely chopped', '2 cloves garlic, minced', '1 tablespoon ginger, minced', '1 tablespoon curry powder', '1 teaspoon turmeric powder', '1 tablespoon olive oil', 'Salt to taste', '2 cups vegetable broth (low sodium)', '1 cup spinach, chopped', 'Juice of 1 lime'], 'instructions': ['Prepare the Ingredients: Rinse the red lentils under cold water until the water runs clear. Set aside.', 'Sauté Aromatics: In a large pot, heat the olive oil over medium heat. Add the chopped onion and sauté until translucent (about 5 minutes). Add minced garlic and ginger, cooking for another minute until fragrant.', 'Add Spices: Stir in the curry powder and turmeric, cooking for an additional minute to release the flavors.', 'Cook Lentils: Add the rinsed lentils to the pot, followed by the vegetable broth and coconut milk. Bring to a boil, then reduce heat to low and simmer for about 20-25 minutes, or until lentils are tender.', 'Finish the Curry: Stir in the chopped spinach and lime juice. Season with salt to taste. Simmer for an additional 5 minutes.'], 'why_healthier': 'This recipe is rich in plant-based proteins from lentils, which help keep you full and satisfied while being low in calories. The use of coconut milk provides healthy fats that can support metabolism.'}, 'dinner': {'name': 'Crispy Tofu & Brussels Sprouts with Maple Mustard Glaze', 'cuisine_culture': 'Midwest Heartland', 'total_calories': 600, 'ingredients': ['14 oz firm tofu (drained and pressed)', '2 tablespoons cornstarch', '1 tablespoon olive oil', 'Salt and pepper to taste', '2 cups Brussels sprouts (halved)', '1 tablespoon olive oil', 'Salt and pepper to taste', '2 tablespoons pure maple syrup', '1 tablespoon Dijon mustard', '1 tablespoon apple cider vinegar', '1 teaspoon garlic powder', '1 teaspoon onion powder'], 'instructions': ['Preheat your oven to 400 ...
# Day 7 completed
# {'breakfast': {'name': 'Aussie Avocado Toast with Feta and Cherry Tomatoes', 'cuisine_culture': 'Australian', 'total_calories': 600, 'ingredients': ['2 slices of whole grain or low-carb bread', '1 medium ripe avocado', '1 oz feta cheese, crumbled', '1 cup cherry tomatoes, halved', '1 tablespoon olive oil', '1 tablespoon lemon juice', 'Salt and pepper to taste', 'Fresh herbs (like basil or parsley) for garnish (optional)'], 'instructions': ['Toast the Bread: Start by toasting the slices of whole grain or low-carb bread until they are golden brown and crispy.', 'Prepare the Avocado: While the bread is toasting, cut the avocado in half, remove the pit, and scoop the flesh into a bowl. Mash the avocado with a fork until it reaches your desired consistency (smooth or chunky).', 'Season the Avocado: Add lemon juice, salt, and pepper to the mashed avocado. Mix well to combine the flavors.', 'Prepare the Cherry Tomatoes: In a separate bowl, combine the halved cherry tomatoes with olive oil, salt, and pepper. Toss gently to coat.', 'Assemble the Toast: Spread the seasoned avocado evenly over the toasted bread slices.', 'Top with Feta and Tomatoes: Sprinkle the crumbled feta cheese over the avocado toast, then top with the seasoned cherry tomatoes.', 'Garnish: If desired, add fresh herbs on top for added flavor and presentation.', 'Serve Immediately: Enjoy your Aussie Avocado Toast warm, as a delicious and nutritious breakfast!'], 'why_healthier': 'This recipe is designed to be nutrient-dense while remaining low in carbohydrates. The combination of healthy fats from the avocado and olive oil, along with the fiber from the whole grain bread and cherry tomatoes, helps keep you full and satisfied. The protein from the feta cheese aids in muscle maintenance, which is essential for fat loss. Additionally, the use of fresh ingredients ensures that you are consuming whole foods that are beneficial for overall health.'}, 'lunch': {'name': 'Yaki Udon with Tofu and Bok Choy', 'cuisine_culture': 'Japanese', 'total_calories': 600, 'ingredients': ['200g Udon noodles (whole grain or low-carb option)', '150g firm tofu, cubed', '2 cups bok choy, chopped', '1 medium carrot, julienned', '1 bell pepper, sliced (any color)', '2 green onions, chopped', '2 cloves garlic, minced', '1 tablespoon ginger, minced', '2 tablespoons low-sodium soy sauce', '1 tablespoon sesame oil', '1 tablespoon rice vinegar', '1 teaspoon chili paste (optional, for heat)', 'Salt and pepper to taste', 'Sesame seeds for garnish (optional)'], 'instructions': ['Prepare the Tofu: Press the tofu to remove excess moisture. Cut it into cubes. In a non-stick skillet, heat 1/2 tablespoon of sesame oil over medium heat. Add the tofu and cook until golden brown on all sides. Remove from the skillet and set aside.', 'Cook the Vegetables: In the same skillet, add the remaining sesame oil. Add minced garlic and ginger, sautéing for about 30 seconds until fragrant. Add the carrot, bell pepper, and bok choy. Stir-fry for about 3-4 minutes until the vegetables are tender but still crisp.', 'Cook the Udon Noodles: In a separate pot, bring water to a boil. Add the udon noodles and cook according to package instructions (typically about 3-5 minutes). Drain and rinse under cold water to stop cooking.', 'Combine Ingredients: Add the cooked udon noodles to the skillet with the vegetables. Pour in the low-sodium soy sauce, rice vinegar, and chili paste (if using). Toss everything together gently to combine and heat through.', 'Add Tofu: Gently fold in the cooked tofu and green onions. Season with salt and pepper to taste.', 'Serve: Plate the Yaki Udon and sprinkle with sesame seeds if desired. Enjoy your healthy, delicious meal!'], 'why_healthier': 'Tofu is a great source of plant-based protein, which helps to keep you full and supports muscle maintenance during weight loss. Using whole grain or low-carb udon noodles helps to control carbohydrate intake while still providing fiber. The bok choy, carrots, an ...

# %%
full_meal_plan
# Out:
# {0: {'breakfast': {'name': 'Shakshuka with Spinach and Feta',
#    'cuisine_culture': 'Israeli',
#    'total_calories': 600,
#    'ingredients': ['2 tablespoons olive oil',
#     '1 medium onion, diced',
#     '2 cloves garlic, minced',
#     '1 red bell pepper, diced',
#     '1 teaspoon ground cumin',
#     '1 teaspoon smoked paprika',
#     '1 can (14 oz) diced tomatoes (no added sugar)',
#     '4 large eggs',
#     '2 cups fresh spinach',
#     '1/2 cup feta cheese, crumbled',
#     'Salt and pepper to taste',
#     'Fresh parsley or cilantro for garnish (optional)'],
#    'instructions': ['In a large skillet, heat the olive oil over medium heat.',
#     'Add the diced onion and red bell pepper to the skillet. Sauté for about 5-7 minutes until the onion is translucent and the peppers are soft. Add the minced garlic and sauté for another minute until fragrant.',
#     'Stir in the ground cumin and smoked paprika, cooking for an additional minute to toast the spices.',
#     'Pour in the canned diced tomatoes (with their juices) and season with salt and pepper. Let the mixture simmer for about 10 minutes, stirring occasionally, until it thickens slightly.',
#     'Add the fresh spinach to the skillet and stir until wilted, about 2-3 minutes.',
#     'Using a spoon, create four small wells in the tomato mixture. Crack an egg into each well.',
#     'Cover the skillet with a lid and cook for about 5-7 minutes, or until the egg whites are set but the yolks are still runny (or to your desired doneness).',
#     'Sprinkle the crumbled feta cheese over the top and cover for another minute to allow it to soften slightly.',
#     'Remove from heat, garnish with fresh parsley or cilantro if desired, and serve warm.'],
#    'why_healthier': 'This Shakshuka recipe is rich in protein from the eggs and feta, which helps to keep you feeling full and satisfied. The inclusion of spinach adds fiber and essential nutrients while keeping the calorie count low. Olive oil provides healthy fats that are beneficial for heart health. The dish is low in carbohydrates, making it suitable for those looking to reduce their carb intake while still enjoying a hearty meal.'},
#   'lunch': {'name': 'Carolina BBQ Tofu Bowl with Collard Greens',
#    'cuisine_culture': 'Southern American',
#    'total_calories': 600,
#    'ingredients': ['1 block (14 oz) firm tofu',
#     '2 tablespoons olive oil',
#     '1/4 cup low-sugar BBQ sauce',
#     '1 teaspoon smoked paprika',
#     '1 teaspoon garlic powder',
#     'Salt and pepper to taste',
#     '4 cups fresh collard greens, chopped',
#     '1 tablespoon olive oil',
#     '1 clove garlic, minced',
#     '1/2 teaspoon red pepper flakes (optional)',
#     '1 tablespoon apple cider vinegar',
#     '1/4 cup diced tomatoes',
#     '1/4 avocado, sliced'],
#    'instructions': ['Press the tofu for about 15-20 minutes to remove excess moisture. Cut it into bite-sized cubes.',
#     'In a bowl, mix the olive oil, BBQ sauce, smoked paprika, garlic powder, salt, and pepper. Add the tofu cubes and toss to coat evenly.',
#     'Preheat a non-stick skillet over medium heat. Add the tofu and cook for about 5-7 minutes until golden brown, turning occasionally.',
#     'In another skillet, heat 1 tablespoon of olive oil over medium heat. Add minced garlic and sauté for 1 minute until fragrant.',
#     'Add the chopped collard greens and red pepper flakes (if using). Sauté for about 5-7 minutes until the greens are tender.',
#     'Stir in the apple cider vinegar and season with salt and pepper to taste.',
#     'In a serving bowl, layer the sautéed collard greens as the base.',
#     'Top with the BBQ tofu, diced tomatoes, and sliced avocado.',
#     'Drizzle any remaining BBQ sauce over the top if desired.',
#     'Serve immediately while warm and enjoy your delicious Carolina BBQ Tofu Bowl!'],
#    'why_healthier': 'This recipe is designed to be low in carbohydrates while providing a satisfying meal rich in protein and healthy fats. The use of tofu as a protein source is beneficial for muscle maintenance and satiety, while the collard greens add fiber and essential nutrients without adding many calories. The healthy fats from olive oil and avocado help keep you full longer and support overall health.'},
#   'dinner': {'name': 'Eggplant Parmesan with Fresh Basil Pesto',
#    'cuisine_culture': 'Italian',
#    'total_calories': 600,
#    'ingredients': ['1 medium eggplant (about 1 lb), sliced into 1/4-inch rounds',
#     '1 cup marinara sauce (preferably homemade or low-sugar)',
#     '1 cup part-skim mozzarella cheese, shredded',
#     '1/2 cup grated Parmesan cheese',
#     '1/2 cup whole wheat breadcrumbs (or almond flour for lower carbs)',
#     '1 large egg, beaten',
#     '1 teaspoon Italian seasoning',
#     'Salt and pepper to taste',
#     'Olive oil spray (for baking)',
#     '2 cups fresh basil leaves',
#     '1/4 cup pine nuts (or walnuts for a lower cost)',
#     '1/4 cup grated Parmesan cheese',
#     '1/2 cup extra virgin olive oil',
#     '2 cloves garlic, minced',
#     'Salt and pepper to taste',
#     'Juice of 1/2 lemon'],
#    'instructions': ['Preheat your oven to 375°F (190°C).',
#     'Sprinkle the eggplant slices with salt and let them sit for about 30 minutes to draw out moisture. Rinse and pat dry.',
#     'Dip each slice in the beaten egg, then coat with breadcrumbs mixed with Italian seasoning, salt, and pepper.',
#     'Place the breaded eggplant slices on a baking sheet lined with parchment paper. Spray lightly with olive oil. Bake for 20-25 minutes, flipping halfway through, until golden and crispy.',
#     'In a food processor, combine basil leaves, pine nuts, Parmesan cheese, garlic, and lemon juice. Pulse until finely chopped. Gradually add olive oil while blending until smooth. Season with salt and pepper to taste.',
#     'In a baking dish, spread a layer of marinara sauce on the bottom. Layer half of the baked eggplant slices, followed by half of the marinara sauce, half of the mozzarella, and half of the Parmesan. Repeat the layers with the remaining ingredients.',
#     'Bake in the oven for an additional 20-25 minutes until the cheese is bubbly and golden.',
#     'Let it cool for a few minutes before serving. Drizzle with fresh basil pesto on top.'],
#    'why_healthier': 'This Eggplant Parmesan is a healthier twist on the classic dish, focusing on whole, minimally processed ingredients. The eggplant is low in calories and high in fiber, which helps keep you full. The use of part-skim cheese reduces fat content while still providing protein and calcium. The fresh basil pesto adds healthy fats from olive oil and nuts, which are beneficial for heart health and satiety.'}},
#  1: {'breakfast': {'name': 'Kelewele with Avocado & Spiced Chickpeas',
#    'cuisine_culture': 'Ghanaian',
#    'total_calories': 600,
#    'ingredients': ['2 medium ripe plantains',
#     '1 tablespoon ginger, grated',
#     '1 tablespoon garlic, minced',
#     '1 teaspoon cayenne pepper',
#     '1 teaspoon paprika',
#     '1 tablespoon coconut oil',
#     'Salt to taste',
#     '1 cup canned chickpeas, drained and rinsed',
#     '1 tablespoon olive oil',
#     '1 teaspoon cumin',
#     '1 teaspoon smoked paprika',
#     'Salt and pepper to taste',
#     '1 medium avocado'],
#    'instructions': ['Peel and slice plantains into bite-sized cubes.',
#     'In a bowl, combine grated ginger, minced garlic, cayenne pepper, paprika, and salt.',
#     'Toss plantain cubes in the spice mixture until evenly coated.',
#     'Heat coconut oil in a frying pan over medium heat. Add spiced plantains and fry until golden brown and crispy, about 5-7 minutes.',
#     'Remove from the pan and place on a paper towel to drain excess oil.',
#     'In a separate pan, heat olive oil over medium heat.',
#     'Add drained chickpeas to the pan and sauté for about 5 minutes.',
#     'Sprinkle cumin, smoked paprika, salt, and pepper over the chickpeas. Stir well and cook for another 3-5 minutes until heated through and slightly crispy.',
#     'Cut the avocado in half, remove the pit, and slice it into wedges.',
#     'On a serving plate, arrange the crispy Kelewele, spiced chickpeas, and avocado slices.',
#     'Optional: Add a sprinkle of fresh herbs like cilantro or parsley for added flavor.'],
#    'why_healthier': 'This recipe is designed to be nutrient-dense while remaining low in refined carbohydrates. The combination of plantains, chickpeas, and avocado provides a balance of healthy fats, fiber, and protein, which helps keep you full longer and supports weight management.'},
#   'lunch': {'name': 'Trinidadian Callaloo with Coconut Spinach',
#    'cuisine_culture': 'Trinidadian',
#    'total_calories': 600,
#    'ingredients': ['2 cups fresh spinach (or 1 cup frozen spinach)',
#     '1 cup callaloo (or substitute with Swiss chard or kale)',
#     '1 cup coconut milk (light)',
#     '1 medium onion, chopped',
#     '2 cloves garlic, minced',
#     '1 medium tomato, diced',
#     '1 bell pepper (any color), diced',
#     '1 tablespoon olive oil',
#     '1 teaspoon thyme (fresh or dried)',
#     '1 teaspoon black pepper',
#     '1/2 teaspoon salt (or to taste)',
#     '1/2 teaspoon cayenne pepper (optional, for heat)',
#     '1/4 cup vegetable broth (low sodium)',
#     '1 tablespoon lime juice',
#     '1/4 cup green onions, chopped (for garnish)'],
#    'instructions': ['Prepare the Ingredients: Wash and chop the spinach, callaloo (or substitute), onion, garlic, tomato, and bell pepper. Set aside.',
#     'Sauté Aromatics: In a large pot, heat the olive oil over medium heat. Add the chopped onion and garlic, and sauté until the onion becomes translucent (about 3-4 minutes).',
#     'Add Vegetables: Stir in the diced tomato and bell pepper. Cook for another 2-3 minutes until the vegetables soften.',
#     'Incorporate Greens: Add the spinach and callaloo to the pot. Stir well to combine with the sautéed vegetables.',
#     'Add Coconut Milk and Seasonings: Pour in the coconut milk and vegetable broth. Add thyme, black pepper, salt, and cayenne pepper (if using). Stir everything together.',
#     'Simmer: Reduce the heat to low, cover the pot, and let it simmer for about 10-15 minutes, allowing the flavors to meld and the greens to wilt.',
#     'Finish with Lime Juice: Once cooked, remove from heat and stir in the lime juice for a fresh flavor boost.',
#     'Serve: Garnish with chopped green onions before serving. Enjoy your Trinidadian Callaloo with Coconut Spinach warm.'],
#    'why_healthier': 'This recipe is designed to be low in calories while being high in nutrients. The use of leafy greens like spinach and callaloo provides fiber, which aids in digestion and promotes satiety, helping to control hunger. The coconut milk adds a creamy texture without excessive calories, and the healthy fats from olive oil and coconut milk can help keep you satisfied longer.'},
#   'dinner': {'name': 'Senegalese Yassa Tofu with Spicy Carrots',
#    'cuisine_culture': 'Senegalese',
#    'total_calories': 600,
#    'ingredients': ['14 oz (400g) firm tofu, pressed and cubed',
#     '1 large onion, thinly sliced',
#     '3 cloves garlic, minced',
#     '1 tablespoon fresh ginger, minced',
#     '2 tablespoons Dijon mustard',
#     '2 tablespoons lemon juice',
#     '1 tablespoon olive oil',
#     '1 teaspoon ground black pepper',
#     '1 teaspoon salt',
#     '1 teaspoon cayenne pepper (optional for heat)',
#     '1 cup vegetable broth',
#     '2 large carrots, sliced into thin rounds',
#     '1 tablespoon olive oil',
#     '1 teaspoon smoked paprika',
#     '1 teaspoon chili flakes',
#     'Salt and pepper to taste',
#     'Fresh parsley for garnish (optional)'],
#    'instructions': ['Press the tofu to remove excess moisture. Cut it into cubes.',
#     'In a bowl, mix the Dijon mustard, lemon juice, minced garlic, ginger, black pepper, salt, and cayenne pepper. Add the tofu cubes and marinate for at least 30 minutes.',
#     'Heat 1 tablespoon of olive oil in a large skillet over medium heat. Add the marinated tofu cubes and cook until golden brown on all sides, about 10-12 minutes. Remove from the skillet and set aside.',
#     'In the same skillet, add the sliced onions and cook until they are soft and translucent, about 5-7 minutes. Add a splash of vegetable broth if they start to stick.',
#     'Return the tofu to the skillet with the onions. Pour in the remaining vegetable broth and stir to combine. Let it simmer for about 5-10 minutes to allow the flavors to meld.',
#     'In a separate pan, heat 1 tablespoon of olive oil over medium heat. Add the sliced carrots and sauté for about 5 minutes.',
#     'Sprinkle with smoked paprika, chili flakes, salt, and pepper. Cook for an additional 5 minutes until the carrots are tender but still crisp.',
#     'Plate the Yassa tofu and serve alongside the spicy carrots. Garnish with fresh parsley if desired.'],
#    'why_healthier': 'This recipe is rich in plant-based protein from tofu, which helps in muscle maintenance and satiety. The use of healthy fats from olive oil provides essential fatty acids without excessive calories. The high fiber content from carrots and onions aids digestion and promotes fullness, making it easier to manage hunger and support weight loss.'}},
#  2: {'breakfast': {'name': 'Cajun Spiced Eggplant & Chickpea Hash with Avocado',
#    'cuisine_culture': 'Louisiana Creole',
#    'total_calories': 600,
#    'ingredients': ['1 medium eggplant (about 1 lb)',
#     '1 can (15 oz) chickpeas, drained and rinsed',
#     '1 medium red bell pepper, diced',
#     '1 small onion, diced',
#     '2 cloves garlic, minced',
#     '1 tablespoon olive oil',
#     '1 teaspoon Cajun seasoning',
#     '1/2 teaspoon smoked paprika',
#     'Salt and pepper to taste',
#     '1 medium avocado, diced',
#     'Fresh cilantro for garnish (optional)'],
#    'instructions': ['Prepare the Ingredients: Start by washing and dicing the eggplant, red bell pepper, and onion. Mince the garlic.',
#     'Sauté the Vegetables: In a large skillet, heat the olive oil over medium heat. Add the diced onion and garlic, and sauté for about 2-3 minutes until the onion becomes translucent.',
#     'Cook the Eggplant: Add the diced eggplant to the skillet. Cook for about 5-7 minutes, stirring occasionally, until the eggplant is tender and slightly browned.',
#     'Add Chickpeas and Spices: Stir in the drained chickpeas, Cajun seasoning, smoked paprika, salt, and pepper. Cook for an additional 5 minutes, allowing the flavors to meld together.',
#     'Incorporate the Bell Pepper: Add the diced red bell pepper to the skillet and cook for another 3-4 minutes until the pepper is tender but still crisp.',
#     'Serve: Remove from heat and top the hash with diced avocado. Garnish with fresh cilantro if desired.',
#     'Enjoy: Serve warm and enjoy your nutritious breakfast!'],
#    'why_healthier': 'This Cajun Spiced Eggplant & Chickpea Hash is rich in fiber from the eggplant and chickpeas, which helps keep you full longer and supports digestive health. The healthy fats from the avocado provide satiety while also delivering essential nutrients. The use of spices not only adds flavor but can also boost metabolism.'},
#   'lunch': {'name': 'Crispy Tofu & Cabbage Slaw with Apple Cider Vinaigrette',
#    'cuisine_culture': 'Midwest Heartland',
#    'total_calories': 600,
#    'ingredients': ['14 oz firm tofu (drained and pressed)',
#     '2 tbsp cornstarch',
#     '1 tbsp olive oil',
#     'Salt and pepper to taste',
#     '2 cups green cabbage, finely shredded',
#     '1 cup red cabbage, finely shredded',
#     '1 carrot, grated',
#     '1/4 cup green onions, chopped',
#     '1/4 cup fresh cilantro, chopped (optional)',
#     '3 tbsp apple cider vinegar',
#     '1 tbsp Dijon mustard',
#     '1 tbsp honey or agave syrup (optional for sweetness)',
#     '2 tbsp olive oil',
#     'Salt and pepper to taste'],
#    'instructions': ['Preheat your oven to 400°F (200°C).',
#     'Cut the pressed tofu into bite-sized cubes.',
#     'In a bowl, toss the tofu cubes with cornstarch, salt, and pepper until evenly coated.',
#     'Spread the tofu on a baking sheet lined with parchment paper and drizzle with olive oil.',
#     'Bake for 25-30 minutes, flipping halfway through, until golden and crispy.',
#     'In a large bowl, combine the green cabbage, red cabbage, grated carrot, green onions, and cilantro (if using).',
#     'In a separate small bowl, whisk together the apple cider vinegar, Dijon mustard, honey or agave syrup, olive oil, salt, and pepper until well combined.',
#     'Pour the vinaigrette over the slaw and toss to coat evenly. Let it sit for about 10 minutes to allow the flavors to meld.',
#     'Once the tofu is crispy, remove it from the oven.',
#     'Serve the crispy tofu over a generous portion of the cabbage slaw.',
#     'Drizzle any remaining vinaigrette over the top for extra flavor.'],
#    'why_healthier': 'This recipe is designed to be low in carbohydrates while providing a satisfying meal rich in plant-based proteins and healthy fats. The crispy tofu serves as a great source of protein, which helps to keep you full and satisfied without excess calories. The cabbage slaw is high in fiber, aiding in digestion and promoting a feeling of fullness. The apple cider vinaigrette adds flavor without excessive calories, making this dish both delicious and nutritious.'},
#   'dinner': {'name': 'Cilantro-Lime Cauliflower Rice with Spicy Black Beans',
#    'cuisine_culture': 'Mexican',
#    'total_calories': 600,
#    'ingredients': ['1 medium head of cauliflower (about 600g)',
#     '1 tablespoon olive oil',
#     '1 lime (juiced and zested)',
#     '1/4 cup fresh cilantro, chopped',
#     '1/2 teaspoon garlic powder',
#     'Salt and pepper to taste',
#     '1 can (15 oz) black beans, rinsed and drained',
#     '1 tablespoon olive oil',
#     '1 small onion, diced',
#     '2 cloves garlic, minced',
#     '1 teaspoon cumin',
#     '1 teaspoon chili powder',
#     '1/2 teaspoon smoked paprika',
#     '1/4 teaspoon cayenne pepper (adjust to taste)',
#     'Salt to taste',
#     '1/4 cup vegetable broth or water',
#     'Optional: sliced jalapeños for garnish'],
#    'instructions': ['Remove the leaves and stem from the cauliflower and cut it into florets.',
#     'In a food processor, pulse the cauliflower florets until they resemble rice grains (about 10-15 pulses). You may need to do this in batches.',
#     'Heat 1 tablespoon of olive oil in a large skillet over medium heat.',
#     'Add the processed cauliflower rice and sauté for about 5-7 minutes until tender.',
#     'Stir in the lime juice, lime zest, garlic powder, chopped cilantro, salt, and pepper. Cook for an additional 2 minutes, then remove from heat.',
#     'In another skillet, heat 1 tablespoon of olive oil over medium heat.',
#     'Add the diced onion and sauté for about 3-4 minutes until translucent.',
#     'Add the minced garlic and cook for another minute until fragrant.',
#     'Stir in the black beans, cumin, chili powder, smoked paprika, cayenne pepper, and salt. Mix well.',
#     'Pour in the vegetable broth or water, and let it simmer for about 5-7 minutes until heated through and slightly thickened.',
#     'On a plate, serve a generous portion of cilantro-lime cauliflower rice topped with the spicy black beans.',
#     'Garnish with sliced jalapeños if desired.'],
#    'why_healthier': 'This recipe is designed to be low in carbohydrates while being high in fiber and plant-based protein, making it ideal for fat loss. The cauliflower rice is a great substitute for traditional rice, significantly reducing calorie intake while still providing volume and satisfaction. The black beans add protein and fiber, keeping you full longer and stabilizing blood sugar levels.'}},
#  3: {'breakfast': {'name': 'Southern-Style Grits with Spinach and Poached Egg',
#    'cuisine_culture': 'Low Country',
#    'total_calories': 600,
#    'ingredients': ['1 cup stone-ground grits (uncooked)',
#     '4 cups water',
#     '1/2 cup unsweetened almond milk',
#     '1/2 cup shredded low-fat cheddar cheese',
#     'Salt and pepper to taste',
#     '2 cups fresh spinach',
#     '1 tablespoon olive oil',
#     '2 cloves garlic, minced',
#     '2 large eggs',
#     '1 tablespoon vinegar (for poaching)',
#     '1 tablespoon chopped fresh parsley',
#     'A sprinkle of red pepper flakes (optional)'],
#    'instructions': ['In a medium saucepan, bring 4 cups of water to a boil. Add a pinch of salt.',
#     'Gradually whisk in the stone-ground grits. Reduce heat to low, cover, and simmer for about 20-25 minutes, stirring occasionally until thickened.',
#     'Once the grits are cooked, stir in the almond milk and shredded cheddar cheese. Mix until creamy and season with salt and pepper to taste. Keep warm.',
#     'In a skillet, heat 1 tablespoon of olive oil over medium heat. Add minced garlic and sauté for about 1 minute until fragrant.',
#     'Add the fresh spinach and cook until wilted, about 2-3 minutes. Season with salt and pepper. Remove from heat.',
#     'In a saucepan, bring water to a gentle simmer and add 1 tablespoon of vinegar.',
#     'Crack each egg into a small bowl. Gently slide the eggs into the simmering water, one at a time. Cook for about 3-4 minutes for a runny yolk or longer if desired.',
#     'Remove the eggs with a slotted spoon and let them drain on a paper towel.',
#     'Spoon the cheesy grits into a bowl. Top with sautéed spinach and place a poached egg on top of each serving.',
#     'Garnish with chopped parsley and a sprinkle of red pepper flakes if desired.'],
#    'why_healthier': 'This recipe is designed to be nutrient-dense while remaining low in calories. The combination of stone-ground grits provides a good source of fiber, which aids in digestion and keeps you feeling full longer. Spinach is low in calories but high in vitamins and minerals, while the poached eggs offer high-quality protein that supports muscle maintenance and satiety. The use of almond milk and low-fat cheese keeps the dish creamy without adding excessive calories or saturated fat.'},
#   'lunch': {'name': 'Malaysian Nasi Ulam with Tofu and Herbs',
#    'cuisine_culture': 'Malaysian',
#    'total_calories': 600,
#    'ingredients': ['1 cup cauliflower rice',
#     '1/2 cup cooked brown rice',
#     '1/2 cup shredded cabbage',
#     '1/4 cup chopped fresh mint',
#     '1/4 cup chopped fresh cilantro',
#     '1/4 cup chopped green onions',
#     '1/4 cup diced cucumber',
#     '1 tablespoon lime juice',
#     '1 tablespoon olive oil',
#     'Salt and pepper to taste',
#     '200g firm tofu',
#     '1 tablespoon soy sauce',
#     '1 teaspoon sesame oil',
#     '1 teaspoon grated ginger',
#     '1 clove garlic, minced',
#     '1/2 teaspoon turmeric powder'],
#    'instructions': ['Press the tofu to remove excess moisture. Cut it into cubes.',
#     'In a bowl, mix soy sauce, sesame oil, ginger, garlic, and turmeric. Add the tofu cubes and marinate for at least 15 minutes.',
#     'Heat a non-stick skillet over medium heat. Add the marinated tofu and cook until golden brown on all sides, about 8-10 minutes. Remove from heat and set aside.',
#     'In a large bowl, combine cauliflower rice, cooked brown rice, shredded cabbage, mint, cilantro, green onions, and cucumber.',
#     'Drizzle with olive oil and lime juice. Season with salt and pepper to taste. Toss everything together until well mixed.',
#     'On a plate, serve a generous portion of the Nasi Ulam topped with the golden tofu. Garnish with additional herbs if desired.'],
#    'why_healthier': 'This Malaysian Nasi Ulam with Tofu and Herbs is a perfect meal for those looking to lose fat while enjoying a flavorful dish. The use of cauliflower rice significantly reduces the carbohydrate content while increasing fiber intake, which helps keep you full longer. Tofu provides a great source of plant-based protein, essential for muscle maintenance during weight loss. The fresh herbs and vegetables add vitamins, minerals, and antioxidants, contributing to overall health.'},
#   'dinner': {'name': 'Tunisian Vegetable Brik with Harissa Yogurt',
#    'cuisine_culture': 'Tunisian',
#    'total_calories': 600,
#    'ingredients': ['4 sheets of rice paper (or thin phyllo dough)',
#     '1 cup of mixed vegetables (zucchini, bell peppers, carrots, finely chopped)',
#     '1/2 cup of cooked chickpeas (mashed)',
#     '1/4 cup of fresh parsley, chopped',
#     '1/4 cup of green onions, chopped',
#     '1 tsp of cumin powder',
#     '1 tsp of paprika',
#     'Salt and pepper to taste',
#     '1 tbsp of olive oil (for sautéing)',
#     '1 cup of plain Greek yogurt (low-fat)',
#     '2 tbsp of harissa paste (adjust to taste)',
#     '1 tbsp of lemon juice'],
#    'instructions': ['In a skillet, heat the olive oil over medium heat.',
#     'Add the mixed vegetables and sauté for about 5-7 minutes until they are tender.',
#     'Stir in the mashed chickpeas, parsley, green onions, cumin, paprika, salt, and pepper. Cook for an additional 2 minutes. Remove from heat and let it cool slightly.',
#     'If using rice paper, soak each sheet in warm water for about 10 seconds until pliable. If using phyllo, keep it covered with a damp cloth to prevent drying.',
#     'Place a sheet on a clean surface and add a generous spoonful of the vegetable filling in the center.',
#     'Fold the edges over to create a triangle or a pocket, sealing the edges with a little water if necessary.',
#     'Repeat with the remaining sheets and filling.',
#     'Preheat the oven to 375°F (190°C).',
#     'Place the briks on a baking sheet lined with parchment paper. Brush lightly with olive oil.',
#     'Bake for 20-25 minutes or until golden brown and crispy.',
#     'In a bowl, combine the Greek yogurt, harissa paste, lemon juice, and salt. Mix well until smooth.',
#     'Serve the hot briks with a generous dollop of harissa yogurt on the side.'],
#    'why_healthier': 'This Tunisian Vegetable Brik is designed to be low in carbs while being rich in fiber and protein. The use of chickpeas provides plant-based protein and fiber, which helps keep you full longer. The vegetables add essential vitamins and minerals while being low in calories. The Greek yogurt is a great source of protein and probiotics, promoting gut health. Harissa adds flavor without extra calories, making this dish satisfying and nutritious.'}},
#  4: {'breakfast': {'name': 'Posho with Avocado and Tomato Salsa',
#    'cuisine_culture': 'Ugandan',
#    'total_calories': 600,
#    'ingredients': ['1 cup maize flour (cornmeal)',
#     '2 cups water',
#     '1/4 teaspoon salt',
#     '1 medium avocado',
#     '1 medium tomato, diced',
#     '1/4 red onion, finely chopped',
#     '1 tablespoon fresh lime juice',
#     '1 tablespoon fresh cilantro, chopped',
#     'Salt and pepper to taste'],
#    'instructions': ['In a medium saucepan, bring 2 cups of water to a boil. Add 1/4 teaspoon of salt.',
#     'In a separate bowl, mix 1 cup of maize flour with a little cold water to create a smooth paste.',
#     'Once the water is boiling, gradually add the maize flour paste to the boiling water while stirring continuously to avoid lumps.',
#     'Reduce the heat to low and continue stirring for about 10-15 minutes until the mixture thickens and pulls away from the sides of the pan.',
#     'Once cooked, transfer the posho to a plate and shape it into a round or oval mound.',
#     'In a mixing bowl, combine the diced tomato, chopped red onion, and chopped cilantro.',
#     'Cut the avocado in half, remove the pit, and scoop the flesh into the bowl. Gently mash it with a fork to combine with the other ingredients.',
#     'Add lime juice, salt, and pepper to taste. Mix well to combine all the flavors.',
#     'Serve the posho warm, topped with a generous scoop of the avocado and tomato salsa.'],
#    'why_healthier': 'High Fiber: The maize flour and vegetables provide dietary fiber, which aids digestion and promotes a feeling of fullness, helping to control appetite. Healthy Fats: Avocado is rich in monounsaturated fats, which are heart-healthy and can help reduce bad cholesterol levels. Low Carb: This meal is relatively low in carbohydrates, making it suitable for those following a low-carb diet while still providing essential nutrients. Vegetarian: This recipe is entirely plant-based, making it suitable for vegetarians and those looking to incorporate more plant foods into their diet.'},
#   'lunch': {'name': 'Laotian Larb Tofu Salad with Fresh Herbs',
#    'cuisine_culture': 'Laotian',
#    'total_calories': 600,
#    'ingredients': ['14 oz (400g) firm tofu, drained and pressed',
#     '2 tablespoons olive oil',
#     '1 tablespoon soy sauce (low sodium)',
#     '1 tablespoon lime juice',
#     '1 tablespoon rice vinegar',
#     '1 teaspoon chili flakes (adjust to taste)',
#     '1 teaspoon ground coriander',
#     '1 teaspoon ground cumin',
#     '1 cup red cabbage, finely shredded',
#     '1 cup carrots, grated',
#     '1 cup cucumber, diced',
#     '1/2 cup green onions, chopped',
#     '1/2 cup fresh mint leaves, chopped',
#     '1/2 cup fresh cilantro leaves, chopped',
#     '1/4 cup roasted peanuts, crushed (optional)',
#     'Salt and pepper to taste'],
#    'instructions': ['Cut the pressed tofu into small cubes.',
#     'Heat 1 tablespoon of olive oil in a non-stick skillet over medium heat.',
#     'Add the tofu cubes and sauté until golden brown on all sides, about 8-10 minutes.',
#     'Remove from heat and let cool slightly.',
#     'In a small bowl, whisk together the soy sauce, lime juice, rice vinegar, chili flakes, ground coriander, ground cumin, and the remaining tablespoon of olive oil. Adjust seasoning with salt and pepper to taste.',
#     'In a large mixing bowl, combine the shredded red cabbage, grated carrots, diced cucumber, chopped green onions, mint, and cilantro.',
#     'Add the sautéed tofu to the salad mixture.',
#     'Pour the dressing over the salad and gently toss to combine all ingredients evenly.',
#     'Divide the salad into bowls and top with crushed roasted peanuts if desired for added crunch. Enjoy immediately!'],
#    'why_healthier': 'This Laotian Larb Tofu Salad is packed with plant-based protein from tofu, which helps to keep you full and satisfied while supporting muscle maintenance during weight loss. The fresh vegetables provide fiber, which aids in digestion and promotes satiety. The use of healthy fats from olive oil and peanuts (optional) adds flavor and helps in the absorption of fat-soluble vitamins. The low-carb nature of the salad makes it suitable for those looking to reduce carbohydrate intake.'},
#   'dinner': {'name': 'Kiwi-Style Grilled Eggplant with Tomato Salsa',
#    'cuisine_culture': 'New Zealand',
#    'total_calories': 600,
#    'ingredients': ['2 medium eggplants (about 600g)',
#     '2 tablespoons olive oil',
#     '1 teaspoon sea salt',
#     '1 teaspoon black pepper',
#     '1 teaspoon smoked paprika',
#     '1 teaspoon garlic powder',
#     '2 cups cherry tomatoes, diced',
#     '1 small red onion, finely chopped',
#     '1 jalapeño, seeded and minced (optional for heat)',
#     '1/4 cup fresh cilantro, chopped',
#     'Juice of 1 lime',
#     'Salt and pepper to taste',
#     '1 avocado, sliced (for healthy fats)',
#     'Fresh lime wedges'],
#    'instructions': ['Slice the eggplants into 1/2-inch thick rounds.',
#     'Sprinkle with sea salt and let them sit for about 30 minutes to draw out excess moisture. Rinse and pat dry.',
#     'In a small bowl, mix olive oil, black pepper, smoked paprika, and garlic powder. Brush both sides of the eggplant slices with the olive oil mixture.',
#     'Preheat the grill or grill pan over medium heat. Grill the eggplant slices for about 4-5 minutes on each side, or until they are tender and have nice grill marks.',
#     'In a mixing bowl, combine diced cherry tomatoes, red onion, jalapeño (if using), cilantro, and lime juice. Season with salt and pepper to taste. Mix well and let it sit for about 10 minutes to allow flavors to meld.',
#     'Arrange the grilled eggplant on a serving platter. Top with the fresh tomato salsa. Optionally, add sliced avocado on top for added creaminess and healthy fats. Serve with lime wedges on the side.'],
#    'why_healthier': 'This recipe is designed to be low in carbohydrates while being rich in fiber, healthy fats, and plant-based proteins. The grilled eggplant is a low-calorie vegetable that provides essential nutrients and keeps you feeling full. The tomato salsa adds freshness and flavor without adding excessive calories. The use of olive oil provides healthy monounsaturated fats, which can help in managing weight and promoting heart health.'}},
#  5: {'breakfast': {'name': 'Czech Cottage Cheese Pancakes with Berry Compote',
#    'cuisine_culture': 'Czech',
#    'total_calories': 590,
#    'ingredients': ['1 cup (240g) low-fat cottage cheese',
#     '2 large eggs',
#     '1/2 cup (60g) almond flour',
#     '1/4 cup (30g) oat flour',
#     '1 tsp vanilla extract',
#     '1/2 tsp baking powder',
#     '1/4 tsp salt',
#     'Cooking spray or a small amount of coconut oil for frying',
#     '1 cup mixed berries (fresh or frozen, such as blueberries, raspberries, and strawberries)',
#     '1 tbsp honey or maple syrup (optional, adjust based on sweetness preference)',
#     '1 tsp lemon juice',
#     '1/2 tsp cinnamon (optional)'],
#    'instructions': ['In a small saucepan, combine the mixed berries, honey (if using), lemon juice, and cinnamon.',
#     'Cook over medium heat for about 5-7 minutes, stirring occasionally until the berries break down and the mixture thickens slightly. Remove from heat and set aside.',
#     'In a mixing bowl, whisk together the cottage cheese and eggs until well combined.',
#     'Add the almond flour, oat flour, vanilla extract, baking powder, and salt. Mix until a smooth batter forms.',
#     'Heat a non-stick skillet over medium heat and lightly grease it with cooking spray or coconut oil.',
#     'Pour about 1/4 cup of the batter onto the skillet for each pancake. Cook for 3-4 minutes or until bubbles form on the surface and the edges look set.',
#     'Flip the pancakes and cook for an additional 2-3 minutes until golden brown. Repeat with the remaining batter.',
#     'Stack the pancakes on a plate and top with the warm berry compote. Enjoy your delicious Czech breakfast!'],
#    'why_healthier': 'This recipe is designed to be low in carbohydrates while providing a good source of protein from the cottage cheese and eggs, which helps to keep you full and satisfied. The use of almond and oat flour adds healthy fats and fiber, contributing to better digestion and sustained energy levels. The berry compote adds natural sweetness and antioxidants without excessive sugar.'},
#   'lunch': {'name': 'Sri Lankan Coconut Lentil Curry',
#    'cuisine_culture': 'Sri Lankan',
#    'total_calories': 600,
#    'ingredients': ['1 cup red lentils (dry)',
#     '1 can (400ml) light coconut milk',
#     '1 medium onion, finely chopped',
#     '2 cloves garlic, minced',
#     '1 tablespoon ginger, minced',
#     '1 tablespoon curry powder',
#     '1 teaspoon turmeric powder',
#     '1 tablespoon olive oil',
#     'Salt to taste',
#     '2 cups vegetable broth (low sodium)',
#     '1 cup spinach, chopped',
#     'Juice of 1 lime'],
#    'instructions': ['Prepare the Ingredients: Rinse the red lentils under cold water until the water runs clear. Set aside.',
#     'Sauté Aromatics: In a large pot, heat the olive oil over medium heat. Add the chopped onion and sauté until translucent (about 5 minutes). Add minced garlic and ginger, cooking for another minute until fragrant.',
#     'Add Spices: Stir in the curry powder and turmeric, cooking for an additional minute to release the flavors.',
#     'Cook Lentils: Add the rinsed lentils to the pot, followed by the vegetable broth and coconut milk. Bring to a boil, then reduce heat to low and simmer for about 20-25 minutes, or until lentils are tender.',
#     'Finish the Curry: Stir in the chopped spinach and lime juice. Season with salt to taste. Simmer for an additional 5 minutes.'],
#    'why_healthier': 'This recipe is rich in plant-based proteins from lentils, which help keep you full and satisfied while being low in calories. The use of coconut milk provides healthy fats that can support metabolism.'},
#   'dinner': {'name': 'Crispy Tofu & Brussels Sprouts with Maple Mustard Glaze',
#    'cuisine_culture': 'Midwest Heartland',
#    'total_calories': 600,
#    'ingredients': ['14 oz firm tofu (drained and pressed)',
#     '2 tablespoons cornstarch',
#     '1 tablespoon olive oil',
#     'Salt and pepper to taste',
#     '2 cups Brussels sprouts (halved)',
#     '1 tablespoon olive oil',
#     'Salt and pepper to taste',
#     '2 tablespoons pure maple syrup',
#     '1 tablespoon Dijon mustard',
#     '1 tablespoon apple cider vinegar',
#     '1 teaspoon garlic powder',
#     '1 teaspoon onion powder'],
#    'instructions': ['Preheat your oven to 400°F (200°C).',
#     'Cut the pressed tofu into bite-sized cubes.',
#     'In a bowl, toss the tofu cubes with cornstarch, olive oil, salt, and pepper until evenly coated.',
#     'Spread the tofu cubes on a baking sheet lined with parchment paper.',
#     'Bake in the preheated oven for 25-30 minutes, flipping halfway through, until golden and crispy.',
#     'While the tofu is baking, toss the halved Brussels sprouts with olive oil, salt, and pepper in a separate bowl.',
#     'Spread the Brussels sprouts on another baking sheet and roast in the oven for 20-25 minutes, or until tender and caramelized, stirring halfway through.',
#     'In a small bowl, whisk together the maple syrup, Dijon mustard, apple cider vinegar, garlic powder, and onion powder until smooth.',
#     'Once the tofu and Brussels sprouts are done, remove them from the oven.',
#     'Drizzle the maple mustard glaze over the crispy tofu and Brussels sprouts, tossing gently to coat.',
#     'Serve warm and enjoy your delicious, healthy dinner!'],
#    'why_healthier': 'This recipe is designed to be low in carbohydrates while being rich in protein and fiber, which are essential for promoting satiety and reducing overall calorie intake. The use of tofu provides a high-quality plant-based protein source, while Brussels sprouts are low in calories and high in fiber, aiding digestion and keeping you full longer. The maple mustard glaze adds flavor without excessive calories, making it a satisfying yet healthy option.'}},
#  6: {'breakfast': {'name': 'Aussie Avocado Toast with Feta and Cherry Tomatoes',
#    'cuisine_culture': 'Australian',
#    'total_calories': 600,
#    'ingredients': ['2 slices of whole grain or low-carb bread',
#     '1 medium ripe avocado',
#     '1 oz feta cheese, crumbled',
#     '1 cup cherry tomatoes, halved',
#     '1 tablespoon olive oil',
#     '1 tablespoon lemon juice',
#     'Salt and pepper to taste',
#     'Fresh herbs (like basil or parsley) for garnish (optional)'],
#    'instructions': ['Toast the Bread: Start by toasting the slices of whole grain or low-carb bread until they are golden brown and crispy.',
#     'Prepare the Avocado: While the bread is toasting, cut the avocado in half, remove the pit, and scoop the flesh into a bowl. Mash the avocado with a fork until it reaches your desired consistency (smooth or chunky).',
#     'Season the Avocado: Add lemon juice, salt, and pepper to the mashed avocado. Mix well to combine the flavors.',
#     'Prepare the Cherry Tomatoes: In a separate bowl, combine the halved cherry tomatoes with olive oil, salt, and pepper. Toss gently to coat.',
#     'Assemble the Toast: Spread the seasoned avocado evenly over the toasted bread slices.',
#     'Top with Feta and Tomatoes: Sprinkle the crumbled feta cheese over the avocado toast, then top with the seasoned cherry tomatoes.',
#     'Garnish: If desired, add fresh herbs on top for added flavor and presentation.',
#     'Serve Immediately: Enjoy your Aussie Avocado Toast warm, as a delicious and nutritious breakfast!'],
#    'why_healthier': 'This recipe is designed to be nutrient-dense while remaining low in carbohydrates. The combination of healthy fats from the avocado and olive oil, along with the fiber from the whole grain bread and cherry tomatoes, helps keep you full and satisfied. The protein from the feta cheese aids in muscle maintenance, which is essential for fat loss. Additionally, the use of fresh ingredients ensures that you are consuming whole foods that are beneficial for overall health.'},
#   'lunch': {'name': 'Yaki Udon with Tofu and Bok Choy',
#    'cuisine_culture': 'Japanese',
#    'total_calories': 600,
#    'ingredients': ['200g Udon noodles (whole grain or low-carb option)',
#     '150g firm tofu, cubed',
#     '2 cups bok choy, chopped',
#     '1 medium carrot, julienned',
#     '1 bell pepper, sliced (any color)',
#     '2 green onions, chopped',
#     '2 cloves garlic, minced',
#     '1 tablespoon ginger, minced',
#     '2 tablespoons low-sodium soy sauce',
#     '1 tablespoon sesame oil',
#     '1 tablespoon rice vinegar',
#     '1 teaspoon chili paste (optional, for heat)',
#     'Salt and pepper to taste',
#     'Sesame seeds for garnish (optional)'],
#    'instructions': ['Prepare the Tofu: Press the tofu to remove excess moisture. Cut it into cubes. In a non-stick skillet, heat 1/2 tablespoon of sesame oil over medium heat. Add the tofu and cook until golden brown on all sides. Remove from the skillet and set aside.',
#     'Cook the Vegetables: In the same skillet, add the remaining sesame oil. Add minced garlic and ginger, sautéing for about 30 seconds until fragrant. Add the carrot, bell pepper, and bok choy. Stir-fry for about 3-4 minutes until the vegetables are tender but still crisp.',
#     'Cook the Udon Noodles: In a separate pot, bring water to a boil. Add the udon noodles and cook according to package instructions (typically about 3-5 minutes). Drain and rinse under cold water to stop cooking.',
#     'Combine Ingredients: Add the cooked udon noodles to the skillet with the vegetables. Pour in the low-sodium soy sauce, rice vinegar, and chili paste (if using). Toss everything together gently to combine and heat through.',
#     'Add Tofu: Gently fold in the cooked tofu and green onions. Season with salt and pepper to taste.',
#     'Serve: Plate the Yaki Udon and sprinkle with sesame seeds if desired. Enjoy your healthy, delicious meal!'],
#    'why_healthier': 'Tofu is a great source of plant-based protein, which helps to keep you full and supports muscle maintenance during weight loss. Using whole grain or low-carb udon noodles helps to control carbohydrate intake while still providing fiber. The bok choy, carrots, and bell peppers add fiber, which aids digestion and promotes satiety. Sesame oil provides healthy fats that are essential for nutrient absorption and overall health.'},
#   'dinner': {'name': 'Croatian Stuffed Peppers with Quinoa & Feta',
#    'cuisine_culture': 'Croatian',
#    'total_calories': 600,
#    'ingredients': ['4 medium bell peppers',
#     '1 cup quinoa',
#     '2 cups vegetable broth',
#     '1 cup feta cheese',
#     '1 cup spinach',
#     '1 medium onion',
#     '2 cloves garlic',
#     '1 teaspoon olive oil',
#     '1 teaspoon dried oregano',
#     '1 teaspoon paprika',
#     'Salt and pepper',
#     'Fresh parsley'],
#    'instructions': ['Preheat your oven to 375°F (190°C).',
#     'Rinse the quinoa under cold water. In a medium saucepan, combine the quinoa and vegetable broth. Bring to a boil, then reduce heat to low, cover, and simmer for about 15 minutes or until the quinoa is fluffy and the liquid is absorbed. Remove from heat and let it sit covered for 5 minutes.',
#     'In a skillet, heat the olive oil over medium heat. Add the diced onion and sauté for 3-4 minutes until translucent. Add the minced garlic and cook for another minute until fragrant. Stir in the chopped spinach and cook until wilted. Season with oregano, paprika, salt, and pepper.',
#     'In a large bowl, combine the cooked quinoa, sautéed vegetables, and crumbled feta cheese. Mix well until all ingredients are evenly distributed.',
#     'While the filling cools slightly, wash the bell peppers and cut the tops off. Remove the seeds and membranes carefully.',
#     'Generously fill each bell pepper with the quinoa and feta mixture. Place the stuffed peppers upright in a baking dish.',
#     'Cover the baking dish with aluminum foil and bake in the preheated oven for 25-30 minutes. Remove the foil and bake for an additional 10 minutes to slightly brown the tops.',
#     'Remove from the oven and let cool for a few minutes. Garnish with fresh parsley if desired. Serve warm.'],
#    'why_healthier': 'This recipe is designed to be low in carbohydrates while being high in fiber and protein, which helps keep you full longer and supports weight management. The use of quinoa provides a complete protein source, while the vegetables add essential nutrients and fiber without excess calories. The reduced-fat feta cheese adds flavor without compromising on health.'}}}
